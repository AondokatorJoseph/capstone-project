# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

from src.data import WasteDatasetLoader, DataPreprocessor
from src.models.model import WasteClassifier
import os 
# Load and preprocess data
loader = WasteDatasetLoader()
preprocessor = DataPreprocessor()

# %%
# Get TrashNet data with verification
print("Loading TrashNet dataset...")
images, labels = loader.load_trashnet()
print(f"Loaded images shape: {images.shape}")
print(f"Loaded labels shape: {labels.shape}")
# Out:
# Loading TrashNet dataset...
# Loading TrashNet dataset...
# Loaded images shape: (2527, 224, 224, 3)
# Loaded labels shape: (2527,)

# %%
print("\nPreprocessing images...")
processed_images, processed_labels = preprocessor.preprocess_images(images, labels)
print(f"Processed images shape: {processed_images.shape}")
print(f"Processed labels shape: {processed_labels.shape}")

# Create splits
data_splits = preprocessor.create_train_val_test_split(processed_images, processed_labels)
# Out:
# Preprocessing images...
# Processed images shape: (5054, 224, 224, 3)
# Processed labels shape: (5054,)

# %%
# Initialize training strategy
strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    # Initialize model
    classifier = WasteClassifier()
    model = classifier.build_model()
    
    # Train model
    history = classifier.train(
        train_data=data_splits['train'],
        validation_data=data_splits['val'],
        epochs=40,
        batch_size=32
    )
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# WARNING:tensorflow:From c:\Users\aondo\OneDrive\Documents\semester three fanshawe college\INFO 6156 Capstone Project\main_capstone\myenv\lib\site-packages\keras\src\backend\tensorflow\core.py:219: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 74s 628ms/step - accuracy: 0.2100 - loss: 1.9094 - val_accuracy: 0.2230 - val_loss: 1.8569
# Epoch 2/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 70s 631ms/step - accuracy: 0.2262 - loss: 1.8030 - val_accuracy: 0.2889 - val_loss: 1.7287
# Epoch 3/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 74s 667ms/step - accuracy: 0.3189 - loss: 1.6719 - val_accuracy: 0.3813 - val_loss: 1.5765
# Epoch 4/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 72s 645ms/step - accuracy: 0.3897 - loss: 1.5464 - val_accuracy: 0.4024 - val_loss: 1.4654
# Epoch 5/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 76s 680ms/step - accuracy: 0.4277 - loss: 1.4508 - val_accuracy: 0.4380 - val_loss: 1.4453
# Epoch 6/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 80s 721ms/step - accuracy: 0.4648 - loss: 1.3691 - val_accuracy: 0.4261 - val_loss: 1.4649
# Epoch 7/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 77s 691ms/step - accuracy: 0.4406 - loss: 1.3622 - val_accuracy: 0.4670 - val_loss: 1.4872
# Epoch 8/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 76s 683ms/step - accuracy: 0.4852 - loss: 1.2596 - val_accuracy: 0.4420 - val_loss: 1.3581
# Epoch 9/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 81s 728ms/step - accuracy: 0.4745 - loss: 1.2582 - val_accuracy: 0.3945 - val_loss: 1.5895
# Epoch 10/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 79s 713ms/step - accuracy: 0.5054 - loss: 1.2195 - val_accuracy: 0.4393 - val_loss: 1.4236
# Epoch 11/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 2480s 23s/step - accuracy: 0.5151 - loss: 1.1719 - val_accuracy: 0.4248 - val_loss: 1.4238
# Epoch 12/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 77s 693ms/step - accuracy: 0.5362 - loss: 1.1436 - val_accuracy: 0.4551 - val_loss: 1.3875
# Epoch 13/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 95s 852ms/step - accuracy: 0.5501 - loss: 1.1176 - val_accuracy: 0.4116 - val_loss: 1.4817

# %%
print("\nLoading COCO dataset for evaluation...")
coco_images, coco_labels = loader.load_coco()
processed_coco_images, processed_coco_labels = preprocessor.preprocess_images(
    coco_images, coco_labels, augment=False
)
# Out:
# Loading COCO dataset for evaluation...
# Loading COCO dataset...
# loading annotations into memory...
# Done (t=13.85s)
# creating index...
# index created!

# %%
print("\nEvaluating model on COCO dataset...")
coco_results = classifier.evaluate_on_coco((processed_coco_images, processed_coco_labels))
# Out:
# Evaluating model on COCO dataset...
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 94s 601ms/step - accuracy: 0.0257 - loss: 3.7180

# %%
# Add evaluation metrics
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Evaluate on TrashNet test set
print("TrashNet Test Set Evaluation:")
test_loss, test_acc = classifier.model.evaluate(
    data_splits['test'][0], 
    data_splits['test'][1], 
    verbose=0
)
print(f"Test accuracy: {test_acc:.4f}")
print(f"Test loss: {test_loss:.4f}")

# Get predictions
y_pred = classifier.model.predict(data_splits['test'][0])
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = data_splits['test'][1]

# Print classification report
print("\nDetailed Classification Report:")
print(classification_report(
    y_true, 
    y_pred_classes, 
    target_names=['glass', 'paper', 'cardboard', 'plastic', 'metal', 'trash']
))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_true, y_pred_classes)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['glass', 'paper', 'cardboard', 'plastic', 'metal', 'trash'],
            yticklabels=['glass', 'paper', 'cardboard', 'plastic', 'metal', 'trash'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()

# COCO dataset evaluation
print("\nCOCO Dataset Evaluation:")
coco_loss, coco_acc = classifier.model.evaluate(
    processed_coco_images,
    processed_coco_labels,
    verbose=0
)
print(f"COCO accuracy: {coco_acc:.4f}")
print(f"COCO loss: {coco_loss:.4f}")
# Out:
# TrashNet Test Set Evaluation:
# Test accuracy: 0.4177
# Test loss: 1.3715
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 17s 647ms/step
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#        glass       0.39      0.28      0.33       151
#        paper       0.35      0.90      0.51       179
#    cardboard       1.00      0.27      0.43       121
#      plastic       0.46      0.22      0.29       144
#        metal       0.55      0.40      0.46       123
#        trash       0.00      0.00      0.00        41
#
#     accuracy                           0.42       759
#    macro avg       0.46      0.35      0.34       759
# weighted avg       0.50      0.42      0.38       759
# c:\Users\aondo\OneDrive\Documents\semester three fanshawe college\INFO 6156 Capstone Project\main_capstone\myenv\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\aondo\OneDrive\Documents\semester three fanshawe college\INFO 6156 Capstone Project\main_capstone\myenv\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\aondo\OneDrive\Documents\semester three fanshawe college\INFO 6156 Capstone Project\main_capstone\myenv\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# COCO Dataset Evaluation:
# COCO accuracy: 0.0277
# COCO loss: 3.7104

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss on TrashNet')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy on TrashNet')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

print("\nCOCO Dataset Evaluation Results:")
print(f"Test Loss: {coco_results['test_loss']:.4f}")
print(f"Test Accuracy: {coco_results['test_accuracy']:.4f}")
# Out:
# COCO Dataset Evaluation Results:
# Test Loss: 3.7104
# Test Accuracy: 0.0277

# %%
# Create save directory and save model weights
project_root =r"C:\Users\aondo\OneDrive\Documents\semester three fanshawe college\INFO 6156 Capstone Project\main_capstone"
model_save_path = os.path.join(project_root, 'models', 'saved_models')
os.makedirs(model_save_path, exist_ok=True)

# Save model weights with correct file extension
weights_path = os.path.join(model_save_path, 'waste_classifier.weights.h5')
classifier.model.save_weights(weights_path)
print(f"Model weights saved to: {weights_path}")

# save complete model for reference later
model_path = os.path.join(model_save_path, 'waste_classifier_full.keras')
classifier.model.save(model_path)
print(f"Full model saved to: {model_path}")
# Out:
# Model weights saved to: C:\Users\aondo\OneDrive\Documents\semester three fanshawe college\INFO 6156 Capstone Project\main_capstone\models\saved_models\waste_classifier.weights.h5
# Full model saved to: C:\Users\aondo\OneDrive\Documents\semester three fanshawe college\INFO 6156 Capstone Project\main_capstone\models\saved_models\waste_classifier_full.keras
